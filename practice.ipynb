# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatilesh-kataria/colab-work/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd
